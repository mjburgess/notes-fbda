# %% [markdown]
# # Practcal Machine Learning
# ### QADMSPML, 5 Days

# %% [markdown]
# ## Admin

# %% [markdown]
# * Fire
# * Toilets
# * Wifi
#     * Training_AP_Public
#     * TheSkillsToSucceed
#
# * Hours:
#     * 9.30am - (4 - 4.30pm)
#     * Breaks:
#         * finishing at 11am
#         * finishing at 1pm
#         * finishing at 2.30pm
#
# * Courseware
#     * USB, Notepad
#     * Released during break
#     * Link

# %% [markdown]
# ## Prerequisites
#
# * high-school Mathematics or above
#     * algebra, functions, plots
#
# * Familiar with basics of..
#     *  programming
#         * (python)
#         * data structures and functions
#     * data analysis including databases
#     * descriptive statistics
#     * typical business problems & use cases
#
# * Comfortable with
#     * analytical and mathematical reasoning
#     * algorithmic thinking
#
# ### Do I need to meet the prerequisties?
#
# You may decide to stay on the course, however it is a course *for practicioners* which covers a wide and complex area. If you do not meet the prerequisties you will struggle with the content and pace of the course.
#
# We can usually arrange attendance on another course instead, which may be of help -- eg., fundamentals of machine learning, fundamnetals of data science, fundamentals of mathematics and statistics; python programming; etc.
#
# ### Topics
#
# * Intro to Data, Science and Business
#
# * Intro to Data Science
#     * Python for Data Science
#     * Statistics & Exploratory Data Analysis
#
# * Intro to Machine Learning
#     * Problems & Solutions
#     * Method
#     * Models
#     * Limitations
#
# * Supervised Learning
#     * Choosing Algorithms
#     * Building Models
#     * Selecting Models
#     * Evaluating Models
#
# * Unsupervisd Learning
#     * Clustering
#     * Dimensionality Reduction
#
# * Data Preparation
#     * Imputing
#     * Feature Engineering
#     * Encoding and Transforming
#     * Pipielines
#
# * Deploying ML Models
#     * Workflow
#     * Data Pipelines

# %% [markdown]
# #### Sample Outline
#
# * Module order and length may vary

# %%
import pandas as pd

(mon, tue, wed, thu, fri) = [
    ['Intro to Data, Analytics & AI', 
    'Python Refresher for Data Science',
    'Data Science in Python'],
    
    ['Intro to Machine Learning',
    'Supervised Learning', 
    'Model Selection & Trees'], # blur
    
    [ 'Intro to Neural Networks',
     'Statistics & Evaluation',
     'Developing ML Software'
     ],
    
    [ 'Unsupervised Learning',
      'Data Preparation',
     'Workflow & Pipelines'
      ],
    
    ['ML Project',
     'ML Project', # EXTRA: 'Intro to Deep Learning'
     '-']
]
        
pd.DataFrame({
    t + 1: (mon[t], tue[t], wed[t], thu[t], fri[t]) 
    for t in range(3)
}, index= ['Mon', 'Tue', 'Wed', 'Thu', 'Fri'] )
# Out:
#                                  1                                  2  \
# Mon  Intro to Data, Analytics & AI  Python Refresher for Data Science
# Tue      Intro to Machine Learning                Supervised Learning
# Wed       Intro to Neural Networks            Statistics & Evaluation
# Thu          Unsupervised Learning                   Data Preparation
# Fri                     ML Project                         ML Project
#
#                            3
# Mon   Data Science in Python
# Tue  Model Selection & Trees
# Wed   Developing ML Software
# Thu     Workflow & Pipelines
# Fri                        -

# %% [markdown]
# ### Process
#
# * Demo, Whiteboard
#
# * Notes
#     * Personal Notes
#         * we encourage you to take notes
#         * these aid with understanding & motivation
#     * Reference Notes
#         * typically more than covered in-class
#     * Tailored Notes
#         * exactly what's covered in class
#
# * Exercises
#     * not challenges, pratrice
#     * may include advanced *Extra* questions
#
# * Next Steps
#     * all material made available
#     * video, book, course recommedations
