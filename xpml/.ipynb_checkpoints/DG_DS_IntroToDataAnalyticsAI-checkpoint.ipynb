# %% [markdown]
# # Introduction to Data, Analytics and AI
#
# ### What is "Data" and why do we care?
#
#
# * Getting insight from data and using it to solve problems
#     * find oversight/gaps/omissions in strategy/approach/method
#     * improve (business) process efficiency
#     * create intelligent software
#         * automate business processes
#         * apps for customers
#
#
#
# * Two Branches
#     * Product: Insight
#         * client: the business
#         * goal: to obtain relevant (stragegic) informatino from data
#
#         * eg.,
#              current: marking company tell me what's going on
#              data science: info. on product, info. on sales + high quality
#
#     * Product: Software
#         * client: customer
#         * goal: writing an app that imrpoves their life/etc
#
#         * eg,. alexa, twitter feed, film recoomends
#
# ### Why now?
#
# ### Science & Business

# %% [markdown]
# ### H
# CEO
#     * CTO
#         * Agreeable
#         * BI
#     * Chief Data Science
#         * Disagreeable
#             * Challegne whole decsision making process
#         * Data Sciene, Analysts

# %% [markdown]
# ### How do businesses make decsisinos?
#
# * Gut, Intitution
#     * Senior Managers,
#     * Trends
#
# * Why are CEOs obsessed with trends?
#     * Personal: seen by other peopel as innovative
#         * customers, other ceos, b2b
#     * Business:
#         * differentiation, confience, stragic advn
#
#     * CEO doesnt know what will advant them...
#         * assume that (marketing...)
#         * adopt novel practices.. assuming it will give advantage

# %% [markdown]
# ### Roles, Skills & Techniques
#
# * Technical: Business Intelligence -> Reports, Useful DBs, Restriction on Data for Others, ...
#     * Historical trends / facts
#     * Questions whose answers are essential certain
#
#     * explanation
#         * causes of historical events
#
#     * SQL, relational data, simply structured business data
#     * ETL  / Data Injestion / PIpelines/ "Infrastructure Inudstrial"
#         * Extract, Transform, Load
#         * Making data usable for analysis
#         * Storing and warehousing
#         * Proving offline db
#             * online <- customers,  eg., retail (tills)
#             * offine <- not live    eg., tilsl -> overnight -> offline db
#
#
# * Data Analytics
#     * as BI...
#     * possibly more forward loking
#     * explanatory
#     * more statistical, less ETL
#
# * Strategic Function: Data Science ->
#     * Perusading & Chaging practice
#     * Best/Worst (not true, not correct)
#     * Scientific Method
#         * Explanatory
#         * Evidence
#             * almost everything is evidence
#             * $P(GhostExist | CurtainBlowing) > 0$
#         * Interpretation
#         * Testing (proof)
#         * **Refutation** (disagree)
#             * evidence which *refutes* a belief is definitive!
#         * Essential:
#             * refute everything until one thing remanis
#             * provisionally use that one HYPOTHESIS as a basis for a makign decisino
#         * inhuman:
#             * no "motivations, interests, beliefs, saving-face..."
#
#
# * Automatation Engineer
#     * can sometimes be called "data science"
#     * Might just be using ML
#         * can we implement a predictive system
#
#
# * Big Data
#     * non-traditional methods
#     * tranditional:
#         * structured
#         * sql
#         * business intelligence
#
# * Machine Learning
#     * computational statistical inference
#         * using computers to infer/guess things
#     * with usual goal of predictive (vs. exlpaining)
#
#     * not explanatory, merely associative (predict)
#     * explanatinos: hold universally (given conditions)
#     * association (coincindences): very specific
#
#
# * Artifical Intelligence
#     * Strong AI -- machines which behave as-if (human/intelligence) in general sitatuions
#         * if i take Robot and teach him how to ..., and i change the environment, he can still do that thing
#
#     * Weak AI -- machines which behave as-if (human/intelligence) in highly specific situations in wich the environment is fixed, and stabel
#         * Machine Learning
#
#    * alex, hub,
#
# * Cognitive Services
#
# * Automation
#     * Business process automation
#         * can we out[ut hte excel file fast
#
#
# * Insight
#     * reporting, stragy, core knwolighe,....

# %% [markdown]
# ## ...

# %% [markdown]
# ## Buzzwords -- Marketing Speak
#
# * Data
#     * Insight, Strategy
#
# * Data Science
#     * vs. Analytics / Business Intelligence
#         * Analysis: history, facts, known quantities
#         * Informs action by evidencing intution
#             * confirm, evidence by confimation
#             * reports
#     * Science
#         * Informing action with clear measures of uncertainty, models
#         * Explanation: relationships/models that account for facts
#         * Prediction: use of relationships to guess / infer
#         * refutes, evidences by refutation
#             * rule out bad ideas
#
# * Big Data
#     * alert business to the need for alterative skills, tools, etc.
#     * hire differnt people, doifferent toosl.,
#
#     * `Big data is a field that treats ways to analyze, systematically extract information from, or otherwise deal with data sets that are too large or complex to be dealt with by **traditional data-processing application software**. `
#     * The use of non-traditional tools
#         * tradition: business-intelligence tooling
#             * relational
#             * SQL
#             * querying for facts / historical aggreates
#             * descriptive statistics
#     * Complex
#         * data structure -- unstructured (non-tabular)
#             * images, audio, ...
#         * non-relational structure
#             * graphs, ...
#
#     * (Large) Volume ( > 1TB )
#         * today: 2TB ram, 8 TB HDDs -- trivial
#         * 64 core processor
#     * Block Chain
#         * shared db
#
# * Machine Learning
#     * Compuational, Statistical, INference
#         * Inferring relationships between statistical variables
#             * using computers
#         * Stat Variable = Column = Field
#             * Variable whose values are obtained from some sample
#     * Use Cases
#         * Associative-Predictive
#             * Associative - no reason to connect input -> output
#             * typically: software product
#             * machine should "do the right thing" for *any* reason!
#             * eg., loud voice -> fast, always? no.. but who cares
#
#         * Explanatory-Insightful
#             * need good reason to suppose input -> ouptut
#             * typically: report, insight project, internal focus
#
#         * Exploratory
#             * discovering potential patterns
#
#     * Generalizes to unseen situations
#         * solves problems not explicitly coded
#
#     * Examples
#         * Automated Warehouses
#         * Autonomous Vechicles
#
#
# * Artifical Intelligence
#     * Weak AI
#         * highly specific defintion of problme
#         * automation by a toool
#         * to perform as well or better than human
#         * eg., rock rolling down a hill, or opening a door, beats a child
#
#     * Strong AI
#         * technqiues/skills/etc. which solve one specific problem in environment A, generalize to other problems in differnet environemetnts
#         * eg., driving in dry weather, can still drive in wet weather
#
#     * AI
#     * Neural Networks
#         * Deep Learning
#
# ## Technically-Informed
#
# * Inference
# * Analytics
#     * Predictive Analytics
# * Data Mining
# * Forecasting
#
# ### Skills
# * Software Engineering
#     * the design and production of software using a programing languge
# * Data Engineering
#     * creating, using and deploying data tools
#     * Data Structure
#     * Database Tools
# * Mathematics
#     * practice of formalziing relationsihps
#     * providing a structural account of those relatiojnships
#     * the model ie., the relationship between input->output can be best described by mathematics
# * Statistics
#     * concern measuring, quantifying uncertainity
#     * inference -- going beyond the mere historical data pints
#     * descriptive -- summaries, aggreates, quantities that describe history

# %% [markdown]
# ## Data Science
#
# * Getting insight from data and using it to solve problems
#     * find oversight/gaps/omissions in strategy/approach/method
#     * improve (business) process efficiency
#     * create intelligent software
#         * automate business processes
#         * apps for customers
#
#
#
# * Two Branches
#     * Product: Insight
#         * client: the business
#         * goal: to obtain relevant (stragegic) informatino from data
#
#         * eg.,
#              current: marking company tell me what's going on
#              data science: info. on product, info. on sales + high quality
#
#     * Product: Software
#         * client: customer
#         * goal: writing an app that imrpoves their life/etc
#
#         * eg,. alexa, twitter feed, film recoomends

# %% [markdown]
# * Machine Learning
#     * hiding stats with python
#
# ## Why Skills
#
# * way of thinking / Behaviour, Cognative
#     * disagreeable: argumentative, critical, stubbon
#         * when instituions are "going wrong"
#             * everyone else is aggreeable
#     * analytical  = cognitive intelligence (abstraction)
#         * break down problem
#         * understand pieces
#         * assemble pieces
#     * business problem solving
#         * engage with institution, strategy, pritoies
#     * social problem solving = emotional intelligenec (behaviour)
#         * your problem is about people (nhs, medical...)
#         * motivation
#         * fight the organization
#         * get the data you need
#         * convince people you're right
#             * changing their mind
#             * persuading non-tehnical
#         * implement new process
#
# * Statistics
#     * that's what we're doing!
# * communication & presentaiton
#     * persuastion

# %% [markdown]
# ## Why are businesses interested in these topcis?
#
# * CEO / C-Level
#     * Strategic Advantage
#         * Competitve Threat
#         * Efficient
#     * may be no advantage
#
# * Is it true?
#
#
# ### How do businesses make decsisinos?
#
# * Gut, Intitution
#     * Senior Managers,
#     * Trends
#
# * Data Science
#     * undo, reverse, undermine, that way of wokring
#
# * Why are CEOs obsessed with trends?
#     * Personal: seen by other peopel as innovative
#         * customers, other ceos, b2b
#     * Business:
#         * differentiation, confience, stragic advn
#
#     * CEO doesnt know what will advant them...
#         * assume that (marketing...)
#         * adopt novel practices.. assuming it will give advantage

# %% [markdown]
# ### Exercise
# #### Time: 15min -- +- 5min
#
# * Consider the role profile of a data scientist:
#     * what subjects are they competent in?
#
# * Consider a business without a data science/insight function:
#     * what reasons would they adopt one?
#
# * Produce a questionaire for a person in, eg,. your own role
#     * (business intellienge or software engineernig)
#     * the goal is to allow them to self-assess theri current skills
#     * and figure out what skills they need to expand
#
#
# * Produce a mini-questionaire for a business (with a BI function but no data insight)
#     * the goal is to allow the business to self-assess on what their needs are, and what they need to get there
#         * consider questions on: data analytics, big data, data science
#         * consider questons on: current workforce, current needs, skills gaps, etc.

# %% [markdown]
# ## Solution

# %%
import pandas as pd

roleq = [
    'Statistical skills',
    'Analytical Problem solving skills',
    'Business Problem solving skills',
    'Social Problem solving skills',
    'Data Pipelines and Architecutres',
    'Software Engineering and Programming',
    'Communication & Presentation',
    'Critical Thinking',
    'Confidence & Willing to Challenge (disagreeble)',
    'Data Visualization',
    'Big Data Tools & Techniques',
    'Traditional Data Analysis (SQL, BI)',
    'Algorithms & Computer Science',
    'Machine Learning',
    'Business Analysis (Problem & Domain Kowledge)',
    'Mathematical Skills',
]


rolea = ['/10'] * len(roleq)

# %%
pd.DataFrame({
    'Questions': roleq,
    'Answers': rolea,
})
# Out:
#                                           Questions Answers
# 0                                Statistical skills     /10
# 1                 Analytical Problem solving skills     /10
# 2                   Business Problem solving skills     /10
# 3                     Social Problem solving skills     /10
# 4                  Data Pipelines and Architecutres     /10
# 5              Software Engineering and Programming     /10
# 6                      Communication & Presentation     /10
# 7                                 Critical Thinking     /10
# 8   Confidence & Willing to Challenge (disagreeble)     /10
# 9                                Data Visualization     /10
# 10                      Big Data Tools & Techniques     /10
# 11              Traditional Data Analysis (SQL, BI)     /10
# 12                    Algorithms & Computer Science     /10
# 13                                 Machine Learning     /10
# 14    Business Analysis (Problem & Domain Kowledge)     /10
# ...

# %% [markdown]
# * Does every data sciest need all?
#     * NO
# * if so, what's the mionimal?
#     * Well.. maybe 3/10 in everythign
#
# * there are different role profiles given skills;
#     * Statistician (DS)
#     * Software Engineer
#     * machine learning
#     * business analysis/commuications

# %%
bizq = [
    'Can you solve all current and mid-etrm problems with BI?',
    'Where is this new need coming from within the business?',
    'What data are you collecting?',
    'Does this data meet your stategic needs?',
    'Do you have a data workforce that can deliver on these?',
    'Where do you want your business to be in 1, 5, 10 yr?',
    'How do you believe a data insight (science) function will help?',
    'What do you beleive wuld be your first data insight project?',
    'What governance and compliance issues do you forsee in analysis of the data you have?',
    'Who is responsible in yuor org. right now for delivering/manmaging/execut data project?',
    'How are these projects conducted?',
    'What impact do you see transition to an insight-led approach would have?',
    'How do you imagine the transition taking place?'
]

biza = ['?'] * len(bizq)

# %%
pd.DataFrame({
    'Questions': bizq,
    'Answers': biza
})
# Out:
# Empty DataFrame
# Columns: [Questions, Answers]
# Index: []

# %% [markdown]
# sUPOSE YOURE A CONSUILTANT AND... OU'ER HIRED OT AMEK A DATA ISNIGHT FUNCTINO
#
#
# * who do you speak to fist?
#     * CEO <- educated on the process
#         * cghallenging biz, obtaining daat, changing process, persaude#
#
#     * what do you say?
# * who do you hire?
#     * Cheif Data Office (Caroline Cath)
#         * Cheif Data Science
#             * education, inform
#             * hire key employees
#             * assess-biz, make places,
#             * execute transofrmation
#
# * waht are the time lines?
#     * 6mo (small/med) - 6yr (internal)
