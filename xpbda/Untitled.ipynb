# %%
# !pip install pyarrow
# Out:
# ...
#      |█████▍                          | 6.8MB 69kB/s eta 0:08:036     |████                            | 5.1MB 194kB/s eta 0:03:03ERROR: Exception:
# Traceback (most recent call last):
#   File "/Users/mjburgess/anaconda3/lib/python3.7/site-packages/pip/_vendor/urllib3/contrib/pyopenssl.py", line 294, in recv_into
#     return self.connection.recv_into(*args, **kwargs)
#   File "/Users/mjburgess/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py", line 1822, in recv_into
#     self._raise_ssl_error(self._ssl, result)
#   File "/Users/mjburgess/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py", line 1622, in _raise_ssl_error
#     raise WantReadError()
# OpenSSL.SSL.WantReadError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/mjburgess/anaconda3/lib/python3.7/site-packages/pip/_vendor/urllib3/contrib/pyopenssl.py", line 294, in recv_into
#     return self.connection.recv_into(*args, **kwargs)
# ...

# %%
 import pyarrow.parquet as pq
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-dc8a4f7832af> in <module>
# ----> 1 import pyarrow.parquet as pq
#
# ModuleNotFoundError: No module named 'pyarrow'
